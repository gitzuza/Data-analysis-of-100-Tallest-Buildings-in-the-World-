# %% [markdown]
# # Data analysis of 100 Tallest Buildings in the World 🏢

# %% [markdown]
# ## **Introduction**
#
# # This is a list of the tallest buildings across the globe, with information on their name, location, completion, height, material, function, number of floors, and location. There are 100 buildings in this list.
#
#
# Content:
#
#  [Import Libraries](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=VAFfdWeti8JQ&line=1&uniqifier=1)
#
# [Load and Check Data](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=CHxaFt-OkCFB&line=1&uniqifier=1)
#
# [Variable Description](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=Auo6GRqks6os&line=1&uniqifier=1)
#
#
# [Missing Values](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=XkOKU3eqAXdf&line=1&uniqifier=1)
#
# [Unique Values
# ](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=m8mii9Oy7PRG&line=1&uniqifier=1)
#
# [Data Visualization](https://colab.research.google.com/drive/1v-FtLnexnKJ8AzEnvto-8QSX5BooZrQH#scrollTo=ppthyFiyAyYK&line=1&uniqifier=1)
#
# **Source:**
# https://www.skyscrapercenter.com/buildings

# %% [markdown]
# # **Import Libraries** 📚

# %%
import pandas as pd
import seaborn as sns
import plotly.express as px
import numpy as np
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from palettable.colorbrewer.qualitative import Pastel1_7

# %% [markdown]
# #  **Load and Check Data** ✅

# %%
df = pd.read_csv('tallest_completed_buildings.csv')

# %%
df.columns
# Out:
# Index(['RANK', 'NAME', 'CITY', 'COMPLETION', 'HEIGHT', 'FLOORS', 'MATERIAL',
#        'FUNCTION'],
#       dtype='object')

# %%
df.head(10)

# %%
df.tail(10)
# Out:
#                                     NAME         CITY  COMPLETION  \
# 90                  Suning Plaza Tower 1    Zhenjiang        2018
# 91      Tianjin Modern City Office Tower      Tianjin        2016
# 92  Hengqin International Finance Center       Zhuhai        2020
# 93        Tianjin World Financial Center      Tianjin        2011
# 94                             SLS Dubai        Dubai        2020
# 95                 Wilshire Grand Center  Los Angeles        2017
# 96                         DAMAC Heights        Dubai        2018
# 97       Twin Towers Guiyang, East Tower      Guiyang        2020
# 98       Twin Towers Guiyang, West Tower      Guiyang        2020
# 99            Shimao International Plaza     Shanghai        2006
#
#                   HEIGHT  FLOORS   MATERIAL  \
# 90    338 m\n/\n1,109 ft    75.0  composite
# 91    338 m\n/\n1,109 ft    65.0  composite
# 92  337.7 m\n/\n1,108 ft    69.0  composite
# 93  336.9 m\n/\n1,105 ft    75.0  composite
# ...

# %%
df.drop('RANK',axis = 1, inplace = True)

# %%
df.describe()
# Out:
#         COMPLETION      FLOORS  function_office  function_residental  \
# count    99.000000   99.000000        99.000000            99.000000
# mean   2011.808081   83.737374         0.737374             0.353535
# std      13.084246   17.346167         0.442301             0.480500
# min    1931.000000   54.000000         0.000000             0.000000
# 25%    2010.500000   72.500000         0.000000             0.000000
# 50%    2016.000000   82.000000         1.000000             0.000000
# 75%    2019.000000   93.500000         1.000000             1.000000
# max    2021.000000  163.000000         1.000000             1.000000
#
#        function_hotel  function_retail  function_serviced_apartments  \
# count       99.000000        99.000000                     99.000000
# mean         0.424242         0.070707                      0.050505
# std          0.496743         0.257639                      0.220099
# ...

# %% [markdown]
# #**Variable Description** 📘

# %% [markdown]
# Name : Building name
#
# City : City of Building
#
# Completion: Completion year
#
# Height: Building height in meters
#
# Material: Building material
#
# Function: Functions of a building

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 99 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   NAME                          99 non-null     object
#  1   CITY                          99 non-null     object
#  2   COMPLETION                    99 non-null     int64
#  3   HEIGHT                        99 non-null     object
#  4   FLOORS                        99 non-null     float64
#  5   MATERIAL                      99 non-null     object
#  6   FUNCTION                      99 non-null     object
#  7   function_office               99 non-null     int64
#  8   function_residental           99 non-null     int64
#  9   function_hotel                99 non-null     int64
#  10  function_retail               99 non-null     int64
#  11  function_serviced_apartments  99 non-null     int64
# ...

# %% [markdown]
# **Categorical Variable:** NAME, CITY, HEIGHT, MATERIAL, FUNCTION
#
# **Numerical Variable**: COMPLETION,FLOORS

# %% [markdown]
# # **Missing Values** ➖

# %%
df.isnull().sum()
# Out:
# NAME          0
# CITY          0
# COMPLETION    0
# HEIGHT        0
# FLOORS        1
# MATERIAL      0
# FUNCTION      0
# dtype: int64

# %%
df.dropna(subset=['FLOORS'], inplace=True)

# %%
df.isnull().sum()
# Out:
# NAME          0
# CITY          0
# COMPLETION    0
# HEIGHT        0
# FLOORS        0
# MATERIAL      0
# FUNCTION      0
# dtype: int64

# %% [markdown]
# # **Unique Values** ❄

# %%
df.NAME.unique().size
# Out:
# 99

# %%
df.CITY.unique()
# Out:
# array(['Dubai', 'Shanghai', 'Mecca', 'Shenzhen', 'Seoul', 'New York City',
#        'Guangzhou', 'Tianjin', 'Beijing', 'Taipei', 'Hong Kong',
#        'St. Petersburg', 'Ho Chi Minh City', 'Changsha', 'Kuala Lumpur',
#        'Suzhou', 'Nanjing', 'Wuhan', 'Chicago', 'Dongguan', 'Kuwait City',
#        'Busan', 'Nanning', 'Guiyang', 'Riyadh', 'Dalian', 'Abu Dhabi',
#        'Moscow', 'Qingdao', 'Chongqing', 'Shenyang', 'Kunming',
#        'Kaohsiung', 'Philadelphia', 'Jinan', 'Wuxi', 'Zhenjiang',
#        'Zhuhai', 'Los Angeles'], dtype=object)

# %%
df.CITY.unique().size
# Out:
# 39

# %%
df.COMPLETION.unique()
# Out:
# array([2010, 2015, 2012, 2017, 2014, 2016, 2019, 2018, 2004, 2008, 2020,
#        1998, 1974, 2011, 2021, 2009, 1999, 2003, 1996, 1931, 1992, 1990,
#        2013, 2000, 1997, 1973, 1969, 2006])

# %%
df.FLOORS.unique()
# Out:
# array([163., 128., 120., 115., 123.,  94., 111.,  97., 109., 101., 108.,
#         98.,  87.,  81.,  88.,  95.,  66., 103.,  84.,  62.,  85.,  80.,
#         86.,  79.,  68.,  73.,  72.,  69.,  82., 102.,  70.,  78.,  93.,
#         77.,  55.,  92.,  65.,  75.,  54.,  74.,  90.,  60.,  61.,  83.,
#        100.,  71.,  59.])

# %%
df.MATERIAL.unique()
# Out:
# array(['steel/concrete', 'composite', 'concrete', 'steel'], dtype=object)

# %%
df.FUNCTION.unique()
# Out:
# array(['office / residential / hotel', 'hotel / office',
#        'hotel / residential / retail', 'office',
#        'hotel / residential / office / retail',
#        'hotel / residential / office',
#        'hotel / serviced apartments / office', 'residential',
#        'hotel / residential', 'hotel / office / serviced apartments',
#        'residential / hotel', 'residential / office',
#        'residential / hotel / retail', 'hotel', 'residential / retail',
#        'hotel / office / retail',
#        'residential / serviced apartments / hotel',
#        'residential / hotel / office', 'office / hotel',
#        'hotel / serviced apartments / SOHO / office',
#        'serviced apartments / hotel'], dtype=object)

# %% [markdown]
# # **Data Visualization** 📊

# %%
sample  = df.rename(columns={"NAME":"Name","CITY":"City","COMPLETION":"Completion","FLOORS":"Floors","MATERIAL":"Material","FUNCTION":"Function"})

# %%
fig = px.treemap(sample, path=[px.Constant('Floors'),'Name'], values='Floors',hover_data=['Name'], labels = {"name":"name"})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(sample, path=[px.Constant('Tallest office buildings by floors'),'City'], values='Floors', hover_data=['Name'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.treemap(sample, path=[px.Constant('Tallest office buildings by completion'),'Completion'], values='Completion', hover_data=['Name'])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['FLOORS'].hist(bins=100)

# %%
df['COMPLETION'].hist(bins=100)

# %%
df.head(10)
# Out:
#                            NAME           CITY  COMPLETION  \
# 0                  Burj Khalifa          Dubai        2010
# 1                Shanghai Tower       Shanghai        2015
# 2      Makkah Royal Clock Tower          Mecca        2012
# 3        Ping An Finance Center       Shenzhen        2017
# 4             Lotte World Tower          Seoul        2017
# 5        One World Trade Center  New York City        2014
# 6  Guangzhou CTF Finance Centre      Guangzhou        2016
# 7    Tianjin CTF Finance Centre        Tianjin        2019
# 8                   CITIC Tower        Beijing        2018
# 9                    TAIPEI 101         Taipei        2004
#
#                  HEIGHT  FLOORS        MATERIAL  \
# 0    828 m\n/\n2,717 ft   163.0  steel/concrete
# 1    632 m\n/\n2,073 ft   128.0       composite
# 2    601 m\n/\n1,972 ft   120.0  steel/concrete
# 3  599.1 m\n/\n1,965 ft   115.0       composite
# 4  554.5 m\n/\n1,819 ft   123.0       composite
# ...

# %%
df.columns
# Out:
# Index(['NAME', 'CITY', 'COMPLETION', 'HEIGHT', 'FLOORS', 'MATERIAL',
#        'FUNCTION'],
#       dtype='object')

# %%
df.FUNCTION.unique()
# Out:
# array(['office / residential / hotel', 'hotel / office',
#        'hotel / residential / retail', 'office',
#        'hotel / residential / office / retail',
#        'hotel / residential / office',
#        'hotel / serviced apartments / office', 'residential',
#        'hotel / residential', 'hotel / office / serviced apartments',
#        'residential / hotel', 'residential / office',
#        'residential / hotel / retail', 'hotel', 'residential / retail',
#        'hotel / office / retail',
#        'residential / serviced apartments / hotel',
#        'residential / hotel / office', 'office / hotel',
#        'hotel / serviced apartments / SOHO / office',
#        'serviced apartments / hotel'], dtype=object)

# %%
function_office = df['FUNCTION'].replace({'residential / hotel / retail': 0 ,'residential / office': 1, 'residential / hotel': 0 ,'hotel / office / serviced apartments': 1,'residential / hotel / retail ': 0,'office / residential / hotel': 1, 'hotel / residential / retail': 1,'hotel / office': 1, 'hotel / residential / office / retail':1,'hotel / residential / office' :1,'office':1,'hotel / serviced apartments / office':1,'residential':0,
       'hotel / residential':0,'hotel':0,'residential / retail':0,'hotel / office / retail':1,'residential / serviced apartments / hotel':0,'residential / hotel / office':0, 'office / hotel':0,'hotel / serviced apartments / SOHO / office':1,'serviced apartments / hotel':0})

function_residental= df['FUNCTION'].replace({'residential / hotel / retail': 1,'residential / office': 1, 'residential / hotel': 1 ,'hotel / office / serviced apartments': 0,'residential / hotel / retail ': 1,'office / residential / hotel': 1, 'hotel / residential / retail': 1,'hotel / office': 0, 'hotel / residential / office / retail':1,'hotel / residential / office' :1,'office':0,'hotel / serviced apartments / office':0,'residential':1,
       'hotel / residential':1,'hotel':0,'residential / retail':1,'hotel / office / retail':1,'residential / serviced apartments / hotel':1,'residential / hotel / office':1, 'office / hotel':0,'hotel / serviced apartments / SOHO / office':0,'serviced apartments / hotel':0})

function_hotel= df['FUNCTION'].replace({'residential / hotel / retail': 1,'residential / office': 0, 'residential / hotel': 0 ,'hotel / office / serviced apartments': 1,'residential / hotel / retail ': 1,'office / residential / hotel': 1, 'hotel / residential / retail': 1,'hotel / office': 1, 'hotel / residential / office / retail':1,'hotel / residential / office' :1,'office':0,'hotel / serviced apartments / office':1,'residential':0,
       'hotel / residential':1,'hotel':1,'residential / retail':0,'hotel / office / retail':1,'residential / serviced apartments / hotel':1,'residential / hotel / office':1, 'office / hotel':1,'hotel / serviced apartments / SOHO / office':1,'serviced apartments / hotel':1})

function_retail= df['FUNCTION'].replace({'residential / hotel / retail': 1,'residential / office': 1, 'residential / hotel': 1 ,'hotel / office / serviced apartments': 0,'residential / hotel / retail ': 1,'residential / office': 0, 'residential / hotel': 0 ,'hotel / office / serviced apartments': 0,'residential / hotel / retail ': 1,'office / residential / hotel': 0, 'hotel / residential / retail': 1,'hotel / office': 0, 'hotel / residential / office / retail':1,'hotel / residential / office' :0,'office':0,'hotel / serviced apartments / office':0,'residential':0,
       'hotel / residential':0,'hotel':0,'residential / retail':1,'hotel / office / retail':1,'residential / serviced apartments / hotel':0,'residential / hotel / office':0, 'office / hotel':0,'hotel / serviced apartments / SOHO / office':0,'serviced apartments / hotel':0})

function_serviced_apartments= df['FUNCTION'].replace({'residential / office': 0,'residential / hotel / retail': 0, 'residential / hotel': 0 ,'hotel / office / serviced apartments': 1,'residential / hotel / retail ': 0,'office / residential / hotel': 0, 'hotel / residential / retail': 0,'hotel / office': 0, 'hotel / residential / office / retail':0,'hotel / residential / office' :0,'office':0,'hotel / serviced apartments / office':1,'residential':0,
       'hotel / residential':0,'hotel':0,'residential / retail':0,'hotel / office / retail':0,'residential / serviced apartments / hotel':1,'residential / hotel / office':0, 'office / hotel':0,'hotel / serviced apartments / SOHO / office':1,'serviced apartments / hotel':1})

function_SOHO=df['FUNCTION'].replace({'residential / hotel':0,'residential / office': 0, 'residential / hotel': 0 ,'hotel / office / serviced apartments': 0,'hotel / office / serviced apartments': 0,'residential / hotel / retail ': 0,'office / residential / hotel': 0, 'hotel / residential / retail': 0,'hotel / office': 0, 'hotel / residential / office / retail':0,'hotel / residential / office' :0,'office':0,'hotel / serviced apartments / office':0,'residential':0,
       'hotel / residential':0,'hotel':0,'residential / retail':0,'hotel / office / retail':0,'residential / serviced apartments / hotel':0,'residential / hotel / office':0, 'residential / hotel / retail': 0,'office / hotel':0,'hotel / serviced apartments / SOHO / office':1,'serviced apartments / hotel':0})

# %%
df['function_office'] =function_office

# %%
df['function_residental'] =function_residental

# %%
df['function_hotel'] =function_hotel

# %%
df['function_retail'] =function_retail

# %%
df['function_serviced_apartments'] =function_serviced_apartments

# %%
df['function_SOHO'] =function_SOHO

# %%
df
# Out:
#                                NAME         CITY  COMPLETION  \
# 0                      Burj Khalifa        Dubai        2010
# 1                    Shanghai Tower     Shanghai        2015
# 2          Makkah Royal Clock Tower        Mecca        2012
# 3            Ping An Finance Center     Shenzhen        2017
# 4                 Lotte World Tower        Seoul        2017
# ..                              ...          ...         ...
# 95            Wilshire Grand Center  Los Angeles        2017
# 96                    DAMAC Heights        Dubai        2018
# 97  Twin Towers Guiyang, East Tower      Guiyang        2020
# 98  Twin Towers Guiyang, West Tower      Guiyang        2020
# 99       Shimao International Plaza     Shanghai        2006
#
#                   HEIGHT  FLOORS        MATERIAL  \
# 0     828 m\n/\n2,717 ft   163.0  steel/concrete
# 1     632 m\n/\n2,073 ft   128.0       composite
# 2     601 m\n/\n1,972 ft   120.0  steel/concrete
# ...

# %%
df.sum(axis=0)
# Out:
# NAME                            Burj KhalifaShanghai TowerMakkah Royal Clock T...
# CITY                            DubaiShanghaiMeccaShenzhenSeoulNew York CityGu...
# COMPLETION                                                                 199169
# HEIGHT                          828 m\n/\n2,717 ft632 m\n/\n2,073 ft601 m\n/\n...
# FLOORS                                                                     8290.0
# MATERIAL                        steel/concretecompositesteel/concretecomposite...
# FUNCTION                        office / residential / hotelhotel / officehote...
# function_office                                                                73
# function_residental                                                            35
# function_hotel                                                                 42
# function_retail                                                                 7
# ...

# %%
names = ['Residential', 'Hotel', 'Retail', 'Serviced Apartments','SOHO', 'Office']
size = [35,42,7,5,1,73] 
my_circle = plt.Circle( (0,4), 0.4
                       , color='white')
plt.figure(figsize=(10,10))
from palettable.colorbrewer.qualitative import Pastel1_7
plt.pie(size, labels=names, colors=Pastel1_7.hex_colors)
p = plt.gcf()
p.gca().add_artist(my_circle)

plt.title('Building function',fontsize=20)
# Show the graph
plt.show()

# %%
sns.scatterplot(x="COMPLETION", y="FLOORS",s=50,
             hue="function_office",
            data=df,color="m")

plt.title('Tallest office buildings ', fontsize = 15)
plt.legend(('office','not office'),title='Office function')

# %%
sns.scatterplot(x="COMPLETION", y="FLOORS",s=50,
             hue="function_residental",
            data=df,color="m")

plt.title('Tallest office buildings ', fontsize = 15)
plt.legend(('residental','not residental'),title='Residental function')

# %%
sns.scatterplot(x="COMPLETION", y="FLOORS",s=50,
             hue="function_hotel",
            data=df,color="m")

plt.title('Tallest office buildings ', fontsize = 15)
plt.legend(('hotel','not hotel'),title='Hotel function')

# %%
sns.scatterplot(x='COMPLETION',y='CITY',data=df.sort_values('FLOORS').tail(5))
plt.title('Tallest office buildings ', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Tallest office buildings ')

# %%
sns.scatterplot(x='COMPLETION',y='FLOORS',data=df.sort_values('FLOORS').tail(10))
plt.title('Tallest buildings ', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Tallest buildings ')

# %%
sns.scatterplot(x='CITY',y='FLOORS',data=df.sort_values('FLOORS').tail(5))
plt.title('Tallest buildings ', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Tallest buildings ')

# %%
sns.scatterplot(x='FLOORS',y='CITY',data=df.sort_values('FLOORS').tail(40))
plt.title('40 Tallest buildings ', fontsize = 15)
# Out:
# Text(0.5, 1.0, '40 Tallest buildings ')

# %%
sns.scatterplot(x="COMPLETION", y="FLOORS",s=50,
             hue="MATERIAL",
            data=df,color="m")

plt.title('Tallest office buildings ', fontsize = 15)
# Out:
# Text(0.5, 1.0, 'Tallest office buildings ')

# %%
sns.set_theme(style="darkgrid")
sns.displot(
    df, x="FLOORS", col="FUNCTION", binwidth=3, height=3,
     facet_kws=dict(margin_titles=True)
)
